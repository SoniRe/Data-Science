# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 3, 20)
y = x ** x

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x=df['sex'], hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(x ** 2)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.barplot(x=x, y=y)
# Out:
# <Axes: >

# %%
sns.barplot(x=df['sex'], y=df['tip'], estimator=np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='tip', y='day', data=df)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.pairplot(df)

# %%
labels = ['Female', 'Male']
values = [300, 400]

plt.pie(values, labels=labels, )
# Out:
# ([<matplotlib.patches.Wedge at 0x20b9af5c910>,
#   <matplotlib.patches.Wedge at 0x20b9af5cb90>],
#  [Text(0.2447729506452284, 1.072420720907811, 'Female'),
#   Text(-0.24477260120619015, -1.0724208006649047, 'Male')])
