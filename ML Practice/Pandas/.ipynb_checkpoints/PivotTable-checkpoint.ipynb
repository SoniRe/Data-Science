# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Pivot Tables (Used in HeatMaps)**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)
df
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    762     18   John
# 1  2023-01-02       B   West    562     22   Mary
# 2  2023-01-03       C  North    846     59    Bob
# 3  2023-01-04       D  South    780     48  Alice
# 4  2023-01-05       A   East    807     67   John
# 5  2023-01-06       B   West    349     26   Mary
# 6  2023-01-07       C  North    702     14    Bob
# 7  2023-01-08       D  South    544     65  Alice
# 8  2023-01-09       A   East    194     63   John
# 9  2023-01-10       B   West    148     40   Mary
# 10 2023-01-11       C  North    186     51    Bob
# 11 2023-01-12       D  South    834     27  Alice
# 12 2023-01-13       A   East    171     67   John
# 13 2023-01-14       B   West    604     66   Mary
# 14 2023-01-15       C  North    623     10    Bob
# 15 2023-01-16       D  South    406     50  Alice
# 16 2023-01-17       A   East    828     92   John
# 17 2023-01-18       B   West    408     75   Mary
# 18 2023-01-19       C  North    234     18    Bob
# 19 2023-01-20       D  South    365     25  Alice

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     762.0    NaN    NaN    NaN
# North      NaN    NaN  623.0    NaN
# South      NaN    NaN    NaN  544.0
# West       NaN  408.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product',aggfunc='median')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     762.0    NaN    NaN    NaN  67.0   NaN   NaN   NaN
# North      NaN    NaN  623.0    NaN   NaN   NaN  18.0   NaN
# South      NaN    NaN    NaN  544.0   NaN   NaN   NaN  48.0
# West       NaN  408.0    NaN    NaN   NaN  40.0   NaN   NaN

# %% [markdown]
# **Cross Tabs**

# %%
#Same as Pivot Table just use Count
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
